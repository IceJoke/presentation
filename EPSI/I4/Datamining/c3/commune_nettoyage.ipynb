# %%
import pandas as pd

# %% [markdown]
# ### Chargement des données :

# %%
communes = pd.read_csv('data/correspondance-code-insee-code-postal.csv', 
                       sep=";", 
                       encoding='utf-8')

# %%
communes.shape
# Out:
# (36742, 17)

# %%
communes.head()
# Out:
#   Code INSEE Code Postal                 Commune    Département  \
# 0      39007       39270                  ALIEZE           JURA
# 1      88086       88600            CHAMP-LE-DUC         VOSGES
# 2      62627       62490  NOYELLES-SOUS-BELLONNE  PAS-DE-CALAIS
# 3      14020       14370                ARGENCES       CALVADOS
# 4      11091       11230                CHALABRE           AUDE
#
#                  Région            Statut  Altitude Moyenne  Superficie  \
# 0         FRANCHE-COMTE    Commune simple             587.0       582.0
# 1              LORRAINE    Commune simple             454.0       396.0
# 2    NORD-PAS-DE-CALAIS    Commune simple              49.0       426.0
# 3       BASSE-NORMANDIE    Commune simple              33.0       987.0
# 4  LANGUEDOC-ROUSSILLON  Chef-lieu canton             455.0      1605.0
#
#    Population                    geo_point_2d  \
# 0         0.2    46.5850122581, 5.58578294146
# 1         0.5    48.1923697643, 6.72962889202
# 2         0.8    50.3091545259, 3.02186108116
# 3         3.5  49.1339723471, -0.158515066328
# 4         1.1    42.9817651679, 2.01049024009
#
#                                            geo_shape  ID Geogla  Code Commune  \
# 0  {"type": "Polygon", "coordinates": [[[5.595422...       8414             7
# 1  {"type": "Polygon", "coordinates": [[[6.728855...       3824            86
# 2  {"type": "Polygon", "coordinates": [[[3.015250...       3944           627
# 3  {"type": "Polygon", "coordinates": [[[-0.13271...      16086            20
# 4  {"type": "Polygon", "coordinates": [[[2.014921...      14175            91
#
#    Code Canton  Code Arrondissement Code Département  Code Région
# 0           21                    2               39           43
# 1            3                    1               88           41
# 2           46                    1               62           31
# 3           34                    2               14           25
# 4           11                    2               11           91

# %% [markdown]
# ### La ville avec le plus de population ?

# %% [markdown]
# Tips : utilisation de la fonction ```.max()```

# %%
max_population = communes['Population'].max()
print max_population
# Out:
# 440.2

# %%
communes[communes['Population'] == max_population]
# Out:
#       Code INSEE                          Code Postal   Commune  \
# 23755      31555  31000/31100/31200/31300/31400/31500  TOULOUSE
#
#          Département         Région                Statut  Altitude Moyenne  \
# 23755  HAUTE-GARONNE  MIDI-PYRENEES  Préfecture de région             148.0
#
#        Superficie  Population                  geo_point_2d  \
# 23755     11809.0       440.2  43.5963814303, 1.43167293364
#
#                                                geo_shape  ID Geogla  \
# 23755  {"type": "Polygon", "coordinates": [[[1.461403...       1420
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 23755           555           99                    3               31
#
#        Code Région
# 23755           73

# %% [markdown]
# #### What's the problem ?

# %% [markdown]
# Paris devrait etre la ville avec le plus de population et pourtant ce n'est pas le cas...

# %%
communes[communes.Commune == "PARIS"] # pas de résultat...
# Out:
# Empty DataFrame
# Columns: [Code INSEE, Code Postal, Commune, Département, Région, Statut, Altitude Moyenne, Superficie, Population, geo_point_2d, geo_shape, ID Geogla, Code Commune, Code Canton, Code Arrondissement, Code Département, Code Région]
# Index: []

# %%
communes.columns
# Out:
# Index([u'Code INSEE', u'Code Postal', u'Commune', u'Département', u'Région',
#        u'Statut', u'Altitude Moyenne', u'Superficie', u'Population',
#        u'geo_point_2d', u'geo_shape', u'ID Geogla', u'Code Commune',
#        u'Code Canton', u'Code Arrondissement', u'Code Département',
#        u'Code Région'],
#       dtype='object')

# %%
communes[(communes[u'Commune'].str.contains("PARIS")) &
        (communes[u'Département'] == "PARIS")].head()
# Out:
#      Code INSEE Code Postal                   Commune Département  \
# 526       75118       75018  PARIS-18E-ARRONDISSEMENT       PARIS
# 1416      75113       75013  PARIS-13E-ARRONDISSEMENT       PARIS
# 2977      75116       75016  PARIS-16E-ARRONDISSEMENT       PARIS
# 4155      75107       75007   PARIS-7E-ARRONDISSEMENT       PARIS
# 8267      75117       75017  PARIS-17E-ARRONDISSEMENT       PARIS
#
#              Région            Statut  Altitude Moyenne  Superficie  \
# 526   ILE-DE-FRANCE  Chef-lieu canton              57.0       604.0
# 1416  ILE-DE-FRANCE  Chef-lieu canton              46.0       713.0
# 2977  ILE-DE-FRANCE  Chef-lieu canton              43.0      1641.0
# 4155  ILE-DE-FRANCE  Chef-lieu canton              34.0       411.0
# 8267  ILE-DE-FRANCE  Chef-lieu canton              40.0       563.0
#
#       Population                  geo_point_2d  \
# 526        200.6  48.8927350746, 2.34871193387
# 1416       182.0  48.8287176845, 2.36246822852
# 2977       169.4   48.8603987604, 2.2620995594
# 4155        57.4  48.8560825982, 2.31243868773
# 8267       168.5  48.8873371665, 2.30748555949
#
#                                               geo_shape  ID Geogla  \
# 526   {"type": "Polygon", "coordinates": [[[2.327115...      36584
# 1416  {"type": "Polygon", "coordinates": [[[2.343909...      36579
# 2977  {"type": "Polygon", "coordinates": [[[2.262784...      36580
# 4155  {"type": "Polygon", "coordinates": [[[2.316633...      12976
# 8267  {"type": "Polygon", "coordinates": [[[2.295145...      36583
#
#       Code Commune  Code Canton  Code Arrondissement Code Département  \
# 526            118           32                    1               75
# 1416           113           27                    1               75
# 2977           116           30                    1               75
# 4155           107           21                    1               75
# 8267           117           31                    1               75
#
#       Code Région
# 526            11
# 1416           11
# 2977           11
# 4155           11
# 8267           11

# %%
communes['Code Arrondissement'].value_counts()
# Out:
# 2    11721
# 1    11151
# 3     8975
# 4     3117
# 5     1177
# 6      366
# 7      186
# 8       31
# 0       17
# 9        1
# Name: Code Arrondissement, dtype: int64

# %%
communes[communes.Statut == u"Capitale d'état"]   # Unicode
# Out:
#       Code INSEE Code Postal                   Commune Département  \
# 15953      75101       75001  PARIS-1ER-ARRONDISSEMENT       PARIS
#
#               Région           Statut  Altitude Moyenne  Superficie  \
# 15953  ILE-DE-FRANCE  Capitale d'état              33.0       181.0
#
#        Population                  geo_point_2d  \
# 15953        17.6  48.8626304852, 2.33629344655
#
#                                                geo_shape  ID Geogla  \
# 15953  {"type": "Polygon", "coordinates": [[[2.344559...      36588
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 15953           101           15                    1               75
#
#        Code Région
# 15953           11

# %% [markdown]
# Seul le premier arrondissement est considéré comme la capital. Il va falloir changer ça :

# %% [markdown]
# Pour ce faire on va prendre tout les Codes Postaux de paris et changer le status

# %%
code_paris = ['75101', '75102', '75103','75104','75105','75106','75107','75108',
               '75109','75110','75111','75112','75113','75114','75115','75116',
               '75117','75118','75119','75120']

# %%
communes.loc[communes['Code INSEE'].isin(code_paris), 'Statut'] = u"Capitale d'état"
# Pour toutes les lignes qui on le Code INSEE dans notre liste, on va changer la valeur de Statut par "Capitale d'état"

# %%
communes[communes.Statut == u"Capitale d'état"]  # Tous les arrondissement de Paris
# Out:
#       Code INSEE Code Postal                   Commune Département  \
# 526        75118       75018  PARIS-18E-ARRONDISSEMENT       PARIS
# 1416       75113       75013  PARIS-13E-ARRONDISSEMENT       PARIS
# 2977       75116       75016  PARIS-16E-ARRONDISSEMENT       PARIS
# 4155       75107       75007   PARIS-7E-ARRONDISSEMENT       PARIS
# 8267       75117       75017  PARIS-17E-ARRONDISSEMENT       PARIS
# 8520       75115       75015  PARIS-15E-ARRONDISSEMENT       PARIS
# 10136      75109       75009   PARIS-9E-ARRONDISSEMENT       PARIS
# 10750      75120       75020  PARIS-20E-ARRONDISSEMENT       PARIS
# 12125      75108       75008   PARIS-8E-ARRONDISSEMENT       PARIS
# 12809      75104       75004   PARIS-4E-ARRONDISSEMENT       PARIS
# 13304      75119       75019  PARIS-19E-ARRONDISSEMENT       PARIS
# 15953      75101       75001  PARIS-1ER-ARRONDISSEMENT       PARIS
# 18439      75106       75006   PARIS-6E-ARRONDISSEMENT       PARIS
# 19544      75112       75012  PARIS-12E-ARRONDISSEMENT       PARIS
# 20620      75110       75010  PARIS-10E-ARRONDISSEMENT       PARIS
# 23264      75111       75011  PARIS-11E-ARRONDISSEMENT       PARIS
# 23321      75102       75002   PARIS-2E-ARRONDISSEMENT       PARIS
# 23565      75103       75003   PARIS-3E-ARRONDISSEMENT       PARIS
# 25453      75114       75014  PARIS-14E-ARRONDISSEMENT       PARIS
# 25556      75105       75005   PARIS-5E-ARRONDISSEMENT       PARIS
#
#               Région           Statut  Altitude Moyenne  Superficie  \
# 526    ILE-DE-FRANCE  Capitale d'état              57.0       604.0
# 1416   ILE-DE-FRANCE  Capitale d'état              46.0       713.0
# 2977   ILE-DE-FRANCE  Capitale d'état              43.0      1641.0
# 4155   ILE-DE-FRANCE  Capitale d'état              34.0       411.0
# 8267   ILE-DE-FRANCE  Capitale d'état              40.0       563.0
# 8520   ILE-DE-FRANCE  Capitale d'état              40.0       846.0
# 10136  ILE-DE-FRANCE  Capitale d'état              44.0       218.0
# 10750  ILE-DE-FRANCE  Capitale d'état              80.0       596.0
# 12125  ILE-DE-FRANCE  Capitale d'état              39.0       385.0
# 12809  ILE-DE-FRANCE  Capitale d'état              33.0       160.0
# 13304  ILE-DE-FRANCE  Capitale d'état              63.0       674.0
# 15953  ILE-DE-FRANCE  Capitale d'état              33.0       181.0
# 18439  ILE-DE-FRANCE  Capitale d'état              40.0       215.0
# 19544  ILE-DE-FRANCE  Capitale d'état              49.0      1636.0
# 20620  ILE-DE-FRANCE  Capitale d'état              45.0       288.0
# 23264  ILE-DE-FRANCE  Capitale d'état              43.0       366.0
# 23321  ILE-DE-FRANCE  Capitale d'état              36.0        99.0
# 23565  ILE-DE-FRANCE  Capitale d'état              35.0       116.0
# 25453  ILE-DE-FRANCE  Capitale d'état              63.0       560.0
# 25556  ILE-DE-FRANCE  Capitale d'état              42.0       252.0
#
#        Population                  geo_point_2d  \
# 526         200.6  48.8927350746, 2.34871193387
# 1416        182.0  48.8287176845, 2.36246822852
# 2977        169.4   48.8603987604, 2.2620995594
# 4155         57.4  48.8560825982, 2.31243868773
# 8267        168.5  48.8873371665, 2.30748555949
# 8520        236.5  48.8401554186, 2.29355937244
# 10136        60.3  48.8768961624, 2.33746024139
# 10750       197.1  48.8631867774, 2.40081982673
# 12125        40.3  48.8725272666, 2.31258256042
# 12809        28.2   48.854228282, 2.35736193814
# 13304       184.8   48.886868623, 2.38469432787
# 15953        17.6  48.8626304852, 2.33629344655
# 18439        43.1  48.8489680919, 2.33267089859
# 19544       142.9  48.8351562307, 2.41980703497
# 20620        95.9  48.8760285569, 2.36111290456
# 23264       152.7  48.8594154976, 2.37874106024
# 23321        22.4  48.8679033789, 2.34410716666
# 23565        35.7  48.8630541318, 2.35936105897
# 25453       137.2  48.8289932116, 2.32710088326
# 25556        61.5  48.8445086596, 2.34985938556
#
#                                                geo_shape  ID Geogla  \
# 526    {"type": "Polygon", "coordinates": [[[2.327115...      36584
# 1416   {"type": "Polygon", "coordinates": [[[2.343909...      36579
# 2977   {"type": "Polygon", "coordinates": [[[2.262784...      36580
# 4155   {"type": "Polygon", "coordinates": [[[2.316633...      12976
# 8267   {"type": "Polygon", "coordinates": [[[2.295145...      36583
# 8520   {"type": "Polygon", "coordinates": [[[2.301320...      36581
# 10136  {"type": "Polygon", "coordinates": [[[2.325754...      16867
# 10750  {"type": "Polygon", "coordinates": [[[2.415973...      36585
# 12125  {"type": "Polygon", "coordinates": [[[2.320781...       9859
# 12809  {"type": "Polygon", "coordinates": [[[2.364320...      11667
# 13304  {"type": "Polygon", "coordinates": [[[2.377012...      36587
# 15953  {"type": "Polygon", "coordinates": [[[2.344559...      36588
# 18439  {"type": "Polygon", "coordinates": [[[2.336591...       9608
# 19544  {"type": "Polygon", "coordinates": [[[2.461247...        668
# 20620  {"type": "Polygon", "coordinates": [[[2.363856...       8429
# 23264  {"type": "Polygon", "coordinates": [[[2.399114...      36586
# 23321  {"type": "Polygon", "coordinates": [[[2.350834...      14312
# 23565  {"type": "Polygon", "coordinates": [[[2.368401...      36582
# 25453  {"type": "Polygon", "coordinates": [[[2.343909...      32539
# 25556  {"type": "Polygon", "coordinates": [[[2.365944...      13706
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 526             118           32                    1               75
# 1416            113           27                    1               75
# 2977            116           30                    1               75
# 4155            107           21                    1               75
# 8267            117           31                    1               75
# 8520            115           29                    1               75
# 10136           109           23                    1               75
# 10750           120           34                    1               75
# 12125           108           22                    1               75
# 12809           104           18                    1               75
# 13304           119           33                    1               75
# 15953           101           15                    1               75
# 18439           106           20                    1               75
# 19544           112           26                    1               75
# 20620           110           24                    1               75
# 23264           111           25                    1               75
# 23321           102           16                    1               75
# 23565           103           17                    1               75
# 25453           114           28                    1               75
# 25556           105           19                    1               75
#
#        Code Région
# 526             11
# 1416            11
# 2977            11
# 4155            11
# 8267            11
# 8520            11
# 10136           11
# 10750           11
# 12125           11
# 12809           11
# 13304           11
# 15953           11
# 18439           11
# 19544           11
# 20620           11
# 23264           11
# 23321           11
# 23565           11
# 25453           11
# 25556           11

# %%
# Population de Paris :
communes[communes.Statut == u"Capitale d'état"]['Population'].sum()
# Out:
# 2234.1

# %%
# Moyenne 
communes[communes.Statut == u"Capitale d'état"]['Population'].mean()
# Out:
# 111.705

# %%
# Max 1
communes[communes.Population == communes[communes.Statut == u"Capitale d'état"]['Population'].max()]
# Out:
#      Code INSEE Code Postal                   Commune Département  \
# 8520      75115       75015  PARIS-15E-ARRONDISSEMENT       PARIS
#
#              Région           Statut  Altitude Moyenne  Superficie  \
# 8520  ILE-DE-FRANCE  Capitale d'état              40.0       846.0
#
#       Population                  geo_point_2d  \
# 8520       236.5  48.8401554186, 2.29355937244
#
#                                               geo_shape  ID Geogla  \
# 8520  {"type": "Polygon", "coordinates": [[[2.301320...      36581
#
#       Code Commune  Code Canton  Code Arrondissement Code Département  \
# 8520           115           29                    1               75
#
#       Code Région
# 8520           11

# %%
# Max 1
communes[communes.Statut == u"Capitale d'état"].sort_values("Population", ascending=0).head(1)
# Out:
#      Code INSEE Code Postal                   Commune Département  \
# 8520      75115       75015  PARIS-15E-ARRONDISSEMENT       PARIS
#
#              Région           Statut  Altitude Moyenne  Superficie  \
# 8520  ILE-DE-FRANCE  Capitale d'état              40.0       846.0
#
#       Population                  geo_point_2d  \
# 8520       236.5  48.8401554186, 2.29355937244
#
#                                               geo_shape  ID Geogla  \
# 8520  {"type": "Polygon", "coordinates": [[[2.301320...      36581
#
#       Code Commune  Code Canton  Code Arrondissement Code Département  \
# 8520           115           29                    1               75
#
#       Code Région
# 8520           11

# %%
# Paris DataFrame :
paris = communes[communes.Statut == u"Capitale d'état"].copy()

# %%
paris['ratio'] = paris['Population'] * 1000 / paris['Superficie']
paris.sort_values('ratio', ascending=0).head()
# Out:
#       Code INSEE Code Postal                   Commune Département  \
# 23264      75111       75011  PARIS-11E-ARRONDISSEMENT       PARIS
# 20620      75110       75010  PARIS-10E-ARRONDISSEMENT       PARIS
# 526        75118       75018  PARIS-18E-ARRONDISSEMENT       PARIS
# 10750      75120       75020  PARIS-20E-ARRONDISSEMENT       PARIS
# 23565      75103       75003   PARIS-3E-ARRONDISSEMENT       PARIS
#
#               Région           Statut  Altitude Moyenne  Superficie  \
# 23264  ILE-DE-FRANCE  Capitale d'état              43.0       366.0
# 20620  ILE-DE-FRANCE  Capitale d'état              45.0       288.0
# 526    ILE-DE-FRANCE  Capitale d'état              57.0       604.0
# 10750  ILE-DE-FRANCE  Capitale d'état              80.0       596.0
# 23565  ILE-DE-FRANCE  Capitale d'état              35.0       116.0
#
#        Population                  geo_point_2d  \
# 23264       152.7  48.8594154976, 2.37874106024
# 20620        95.9  48.8760285569, 2.36111290456
# 526         200.6  48.8927350746, 2.34871193387
# 10750       197.1  48.8631867774, 2.40081982673
# 23565        35.7  48.8630541318, 2.35936105897
#
#                                                geo_shape  ID Geogla  \
# 23264  {"type": "Polygon", "coordinates": [[[2.399114...      36586
# 20620  {"type": "Polygon", "coordinates": [[[2.363856...       8429
# 526    {"type": "Polygon", "coordinates": [[[2.327115...      36584
# 10750  {"type": "Polygon", "coordinates": [[[2.415973...      36585
# 23565  {"type": "Polygon", "coordinates": [[[2.368401...      36582
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 23264           111           25                    1               75
# 20620           110           24                    1               75
# 526             118           32                    1               75
# 10750           120           34                    1               75
# 23565           103           17                    1               75
#
#        Code Région       ratio
# 23264           11  417.213115
# 20620           11  332.986111
# 526             11  332.119205
# 10750           11  330.704698
# 23565           11  307.758621

# %% [markdown]
# Il semble que l'ensemble des villes ayant des arrondissement on ce problème :
#     - Marseille
#     - Lyon

# %% [markdown]
# Faire de même pour Marseille et Lyon (attention, ce ne sont pas des capitals, il faut trouver leurs statuts)

# %%
# Marseille
code_marseille = ['13201', '13202', '13203', '13204', '13205', '13206', '13207', '13208',
                   '13209', '13210', '13211', '13212', '13213', '13214', '13215', '13216']

communes.loc[communes['Code INSEE'].isin(code_marseille), 'Statut'] = u'Préfecture de région'

# %%
# Lyon
code_lyon = ['69001', '69002', '69003', '69004', '69005', '69006', '69007',
             '69008', '69009']

communes.loc[communes['Code INSEE'].isin(code_lyon), 'Statut'] = u'Préfecture de région'

# %%
communes[communes.Commune == "TALENCE"]
# Out:
#       Code INSEE Code Postal  Commune Département     Région  \
# 30273      33522       33400  TALENCE     GIRONDE  AQUITAINE
#
#                  Statut  Altitude Moyenne  Superficie  Population  \
# 30273  Chef-lieu canton              21.0       829.0        40.8
#
#                          geo_point_2d  \
# 30273  44.8060817507, -0.591124592873
#
#                                                geo_shape  ID Geogla  \
# 30273  {"type": "Polygon", "coordinates": [[[-0.59182...      18365
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 30273           522           56                    2               33
#
#        Code Région
# 30273           72

# %% [markdown]
# ### Les métropoles ?

# %% [markdown]
# Il semble qu'il n'y a pas d'informations sur les métropoles (manque d'informations), il va donc falloir trouver cette information :

# %% [markdown]
# **Tips :** https://gist.github.com/armgilles/2e223f931fd11bf8c1ecb3f442a0a537

# %% [markdown]
# - Indiquer si la commune fait partie d'une métropole (variable booléen 0/1)
# - Indiquer le nom de la métrolple

# %%
# list of all code insee city in metropole
# Faire un copié / coller ;)
insee_metropole = {'59350' : 'Lille',
                '59013' : 'Lille',
                '59017' : 'Lille',
                '59044' : 'Lille',
                '59051' : 'Lille',
                '59056' : 'Lille',
                '59090' : 'Lille',
                '59098' : 'Lille',
                '59106' : 'Lille',
                '59128' : 'Lille',
                '59143' : 'Lille',
                '59146' : 'Lille',
                '59152' : 'Lille',
                '59163' : 'Lille',
                '59173' : 'Lille',
                '59670' : 'Lille',
                '59193' : 'Lille',
                '59195' : 'Lille',
                '59196' : 'Lille',
                '59201' : 'Lille',
                '59202' : 'Lille',
                '59208' : 'Lille',
                '59220' : 'Lille',
                '59247' : 'Lille',
                '59250' : 'Lille',
                '59252' : 'Lille',
                '59256' : 'Lille',
                '59275' : 'Lille',
                '59278' : 'Lille',
                '59279' : 'Lille',
                '59281' : 'Lille',
                '59286' : 'Lille',
                '59299' : 'Lille',
                '59303' : 'Lille',
                '59316' : 'Lille',
                '59317' : 'Lille',
                '59320' : 'Lille',
                '59328' : 'Lille',
                '59332' : 'Lille',
                '59339' : 'Lille',
                '59343' : 'Lille',
                '59346' : 'Lille',
                '59352' : 'Lille',
                '59356' : 'Lille',
                '59360' : 'Lille',
                '59367' : 'Lille',
                '59368' : 'Lille',
                '59378' : 'Lille',
                '59386' : 'Lille',
                '59388' : 'Lille',
                '59410' : 'Lille',
                '59421' : 'Lille',
                '59426' : 'Lille',
                '59437' : 'Lille',
                '59457' : 'Lille',
                '59458' : 'Lille',
                '59470' : 'Lille',
                '59482' : 'Lille',
                '59507' : 'Lille',
                '59508' : 'Lille',
                '59512' : 'Lille',
                '59522' : 'Lille',
                '59523' : 'Lille',
                '59524' : 'Lille',
                '59527' : 'Lille',
                '59550' : 'Lille',
                '59553' : 'Lille',
                '59560' : 'Lille',
                '59566' : 'Lille',
                '59585' : 'Lille',
                '59598' : 'Lille',
                '59599' : 'Lille',
                '59602' : 'Lille',
                '59609' : 'Lille',
                '59611' : 'Lille',
                '59009' : 'Lille',
                '59636' : 'Lille',
                '59643' : 'Lille',
                '59646' : 'Lille',
                '59648' : 'Lille',
                '59650' : 'Lille',
                '59653' : 'Lille',
                '59656' : 'Lille',
                '59658' : 'Lille',
                '59660' : 'Lille',
                '33063' : 'Bordeaux',
                '33003' : 'Bordeaux',
                '33004' : 'Bordeaux',
                '33013' : 'Bordeaux',
                '33032' : 'Bordeaux',
                '33039' : 'Bordeaux',
                '33056' : 'Bordeaux',
                '33065' : 'Bordeaux',
                '33075' : 'Bordeaux',
                '33096' : 'Bordeaux',
                '33119' : 'Bordeaux',
                '33162' : 'Bordeaux',
                '33167' : 'Bordeaux',
                '33192' : 'Bordeaux',
                '33069' : 'Bordeaux',
                '33200' : 'Bordeaux',
                '33519' : 'Bordeaux',
                '33249' : 'Bordeaux',
                '33273' : 'Bordeaux',
                '33281' : 'Bordeaux',
                '33312' : 'Bordeaux',
                '33318' : 'Bordeaux',
                '33376' : 'Bordeaux',
                '33434' : 'Bordeaux',
                '33449' : 'Bordeaux',
                '33487' : 'Bordeaux',
                '33522' : 'Bordeaux',
                '33550' : 'Bordeaux',
                '31555' : 'Toulouse',
                '31003' : 'Toulouse',
                '31022' : 'Toulouse',
                '31032' : 'Toulouse',
                '31044' : 'Toulouse',
                '31053' : 'Toulouse',
                '31056' : 'Toulouse',
                '31069' : 'Toulouse',
                '31088' : 'Toulouse',
                '31091' : 'Toulouse',
                '31116' : 'Toulouse',
                '31149' : 'Toulouse',
                '31150' : 'Toulouse',
                '31157' : 'Toulouse',
                '31163' : 'Toulouse',
                '31182' : 'Toulouse',
                '31184' : 'Toulouse',
                '31186' : 'Toulouse',
                '31205' : 'Toulouse',
                '31230' : 'Toulouse',
                '31282' : 'Toulouse',
                '31293' : 'Toulouse',
                '31351' : 'Toulouse',
                '31352' : 'Toulouse',
                '31355' : 'Toulouse',
                '31389' : 'Toulouse',
                '31417' : 'Toulouse',
                '31418' : 'Toulouse',
                '31445' : 'Toulouse',
                '31467' : 'Toulouse',
                '31488' : 'Toulouse',
                '31490' : 'Toulouse',
                '31506' : 'Toulouse',
                '31541' : 'Toulouse',
                '31557' : 'Toulouse',
                '31561' : 'Toulouse',
                '31588' : 'Toulouse',
                '44109' : 'Nantes',
                '44009' : 'Nantes',
                '44018' : 'Nantes',
                '44020' : 'Nantes',
                '44024' : 'Nantes',
                '44026' : 'Nantes',
                '44035' : 'Nantes',
                '44047' : 'Nantes',
                '44074' : 'Nantes',
                '44094' : 'Nantes',
                '44101' : 'Nantes',
                '44114' : 'Nantes',
                '44120' : 'Nantes',
                '44143' : 'Nantes',
                '44150' : 'Nantes',
                '44162' : 'Nantes',
                '44166' : 'Nantes',
                '44171' : 'Nantes',
                '44190' : 'Nantes',
                '44172' : 'Nantes',
                '44194' : 'Nantes',
                '44198' : 'Nantes',
                '44204' : 'Nantes',
                '44215' : 'Nantes',
                '06088' : 'Nice',
                '06006' : 'Nice',
                '06009' : 'Nice',
                '06011' : 'Nice',
                '06013' : 'Nice',
                '06020' : 'Nice',
                '06021' : 'Nice',
                '06025' : 'Nice',
                '06027' : 'Nice',
                '06032' : 'Nice',
                '06033' : 'Nice',
                '06034' : 'Nice',
                '06042' : 'Nice',
                '06046' : 'Nice',
                '06055' : 'Nice',
                '06059' : 'Nice',
                '06060' : 'Nice',
                '06065' : 'Nice',
                '06064' : 'Nice',
                '06066' : 'Nice',
                '06072' : 'Nice',
                '06073' : 'Nice',
                '06074' : 'Nice',
                '06075' : 'Nice',
                '06080' : 'Nice',
                '06102' : 'Nice',
                '06103' : 'Nice',
                '06109' : 'Nice',
                '06110' : 'Nice',
                '06111' : 'Nice',
                '06114' : 'Nice',
                '06117' : 'Nice',
                '06119' : 'Nice',
                '06120' : 'Nice',
                '06121' : 'Nice',
                '06122' : 'Nice',
                '06123' : 'Nice',
                '06126' : 'Nice',
                '06127' : 'Nice',
                '06129' : 'Nice',
                '06144' : 'Nice',
                '06146' : 'Nice',
                '06147' : 'Nice',
                '06149' : 'Nice',
                '06151' : 'Nice',
                '06153' : 'Nice',
                '06156' : 'Nice',
                '06157' : 'Nice',
                '06159' : 'Nice',
                '76005' : 'Rouen',
                '76020' : 'Rouen',
                '76039' : 'Rouen',
                '76056' : 'Rouen',
                '76069' : 'Rouen',
                '76088' : 'Rouen',
                '76108' : 'Rouen',
                '76108' : 'Rouen',
                '76103' : 'Rouen',
                '76116' : 'Rouen',
                '76131' : 'Rouen',
                '76157' : 'Rouen',
                '76165' : 'Rouen',
                '76178' : 'Rouen',
                '76212' : 'Rouen',
                '76216' : 'Rouen',
                '76222' : 'Rouen',
                '76231' : 'Rouen',
                '76237' : 'Rouen',
                '76273' : 'Rouen',
                '76475' : 'Rouen',
                '76282' : 'Rouen',
                '76313' : 'Rouen',
                '76319' : 'Rouen',
                '76322' : 'Rouen',
                '76350' : 'Rouen',
                '76354' : 'Rouen',
                '76366' : 'Rouen',
                '76367' : 'Rouen',
                '76377' : 'Rouen',
                '76378' : 'Rouen',
                '76391' : 'Rouen',
                '76402' : 'Rouen',
                '76410' : 'Rouen',
                '76429' : 'Rouen',
                '76436' : 'Rouen',
                '76451' : 'Rouen',
                '76448' : 'Rouen',
                '76457' : 'Rouen',
                '76464' : 'Rouen',
                '76474' : 'Rouen',
                '76484' : 'Rouen',
                '76486' : 'Rouen',
                '76497' : 'Rouen',
                '76498' : 'Rouen',
                '76513' : 'Rouen',
                '76514' : 'Rouen',
                '76536' : 'Rouen',
                '76540' : 'Rouen',
                '76550' : 'Rouen',
                '76558' : 'Rouen',
                '76560' : 'Rouen',
                '76561' : 'Rouen',
                '76575' : 'Rouen',
                '76591' : 'Rouen',
                '76599' : 'Rouen',
                '76614' : 'Rouen',
                '76617' : 'Rouen',
                '76631' : 'Rouen',
                '76634' : 'Rouen',
                '76636' : 'Rouen',
                '76640' : 'Rouen',
                '76608' : 'Rouen',
                '76681' : 'Rouen',
                '76682' : 'Rouen',
                '76705' : 'Rouen',
                '76709' : 'Rouen',
                '76717' : 'Rouen',
                '76750' : 'Rouen',
                '76753' : 'Rouen',
                '76759' : 'Rouen',
                '67043' : 'Strasbourg',
                '67049' : 'Strasbourg',
                '67118' : 'Strasbourg',
                '67119' : 'Strasbourg',
                '67124' : 'Strasbourg',
                '67131' : 'Strasbourg',
                '67137' : 'Strasbourg',
                '67152' : 'Strasbourg',
                '67204' : 'Strasbourg',
                '67212' : 'Strasbourg',
                '67218' : 'Strasbourg',
                '67256' : 'Strasbourg',
                '67267' : 'Strasbourg',
                '67268' : 'Strasbourg',
                '67296' : 'Strasbourg',
                '67309' : 'Strasbourg',
                '67326' : 'Strasbourg',
                '67343' : 'Strasbourg',
                '67350' : 'Strasbourg',
                '67365' : 'Strasbourg',
                '67378' : 'Strasbourg',
                '67389' : 'Strasbourg',
                '67447' : 'Strasbourg',
                '67471' : 'Strasbourg',
                '67482' : 'Strasbourg',
                '67506' : 'Strasbourg',
                '67519' : 'Strasbourg',
                '67551' : 'Strasbourg',
                '38185' : 'Grenoble',
                '38057' : 'Grenoble',
                '38059' : 'Grenoble',
                '38068' : 'Grenoble',
                '38071' : 'Grenoble',
                '38111' : 'Grenoble',
                '38126' : 'Grenoble',
                '38150' : 'Grenoble',
                '38151' : 'Grenoble',
                '38158' : 'Grenoble',
                '38169' : 'Grenoble',
                '38170' : 'Grenoble',
                '38179' : 'Grenoble',
                '38187' : 'Grenoble',
                '38188' : 'Grenoble',
                '38200' : 'Grenoble',
                '38229' : 'Grenoble',
                '38235' : 'Grenoble',
                '38252' : 'Grenoble',
                '38258' : 'Grenoble',
                '38271' : 'Grenoble',
                '38277' : 'Grenoble',
                '38279' : 'Grenoble',
                '38281' : 'Grenoble',
                '38309' : 'Grenoble',
                '38317' : 'Grenoble',
                '38325' : 'Grenoble',
                '38328' : 'Grenoble',
                '38364' : 'Grenoble',
                '38382' : 'Grenoble',
                '38388' : 'Grenoble',
                '38421' : 'Grenoble',
                '38423' : 'Grenoble',
                '38436' : 'Grenoble',
                '38445' : 'Grenoble',
                '38471' : 'Grenoble',
                '38472' : 'Grenoble',
                '38474' : 'Grenoble',
                '38478' : 'Grenoble',
                '38485' : 'Grenoble',
                '38486' : 'Grenoble',
                '38516' : 'Grenoble',
                '38524' : 'Grenoble',
                '38528' : 'Grenoble',
                '38529' : 'Grenoble',
                '38533' : 'Grenoble',
                '38540' : 'Grenoble',
                '38545' : 'Grenoble',
                '38562' : 'Grenoble',
                '34172' : 'Montpellier',
                '34022' : 'Montpellier',
                '34027' : 'Montpellier',
                '34057' : 'Montpellier',
                '34058' : 'Montpellier',
                '34077' : 'Montpellier',
                '34087' : 'Montpellier',
                '34088' : 'Montpellier',
                '34090' : 'Montpellier',
                '34095' : 'Montpellier',
                '34116' : 'Montpellier',
                '34120' : 'Montpellier',
                '34123' : 'Montpellier',
                '34129' : 'Montpellier',
                '34134' : 'Montpellier',
                '34164' : 'Montpellier',
                '34169' : 'Montpellier',
                '34179' : 'Montpellier',
                '34198' : 'Montpellier',
                '34202' : 'Montpellier',
                '34217' : 'Montpellier',
                '34227' : 'Montpellier',
                '34244' : 'Montpellier',
                '34249' : 'Montpellier',
                '34256' : 'Montpellier',
                '34259' : 'Montpellier', #Saint-Georges-d'Orques(34680) from wiki -> 34259
                '34270' : 'Montpellier',
                '34295' : 'Montpellier',
                '34307' : 'Montpellier',
                '34327' : 'Montpellier',
                '34337' : 'Montpellier',
                '35238' : 'Rennes',
                '35001' : 'Rennes',
                '35022' : 'Rennes',
                '35024' : 'Rennes',
                '35032' : 'Rennes',
                '35039' : 'Rennes',
                '35047' : 'Rennes',
                '35051' : 'Rennes',
                '35055' : 'Rennes',
                '35058' : 'Rennes',
                '35059' : 'Rennes',
                '35065' : 'Rennes',
                '35066' : 'Rennes',
                '35076' : 'Rennes',
                '35079' : 'Rennes',
                '35080' : 'Rennes',
                '35081' : 'Rennes',
                '35088' : 'Rennes',
                '35120' : 'Rennes',
                '35131' : 'Rennes',
                '35139' : 'Rennes',
                '35144' : 'Rennes',
                '35180' : 'Rennes',
                '35189' : 'Rennes',
                '35196' : 'Rennes',
                '35204' : 'Rennes',
                '35206' : 'Rennes',
                '35208' : 'Rennes',
                '35210' : 'Rennes',
                '35216' : 'Rennes',
                '35363' : 'Rennes',
                '35240' : 'Rennes',
                '35245' : 'Rennes',
                '35250' : 'Rennes',
                '35266' : 'Rennes',
                '35275' : 'Rennes',
                '35278' : 'Rennes',
                '35281' : 'Rennes',
                '35315' : 'Rennes',
                '35334' : 'Rennes',
                '35351' : 'Rennes',
                '35352' : 'Rennes',
                '35353' : 'Rennes',
                '29019' : 'Brest',
                '29011' : 'Brest',
                '29061' : 'Brest',
                '29069' : 'Brest',
                '29075' : 'Brest',
                '29189' : 'Brest',
                '29212' : 'Brest',
                '29235' : 'Brest'}

# %%
communes['metropole_name'] = None  # On initialise le nom de la métrole

# %%
insee_metropole.get(x)
# Out:
# 'Brest'

# %%
# Utilisation d'un dictionnaire
# Permet de mapper ID / Valeur
# Pour chaque ligne on prend la valeur de Code Insee et on renvoit la valeur

communes['metropole_name'] = communes['Code INSEE'].apply(lambda x: insee_metropole.get(x))

# %%
communes['metropole_name'].head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: metropole_name, dtype: object

# %%
communes['metropole_name'].value_counts()
# Out:
# Lille          85
# Rouen          70
# Nice           49
# Grenoble       49
# Rennes         43
# Toulouse       37
# Montpellier    31
# Bordeaux       28
# Strasbourg     28
# Nantes         24
# Brest           8
# Name: metropole_name, dtype: int64

# %%
# Variable Booléen pour savoir si une commune est dans uné métropole : 
communes['is_metropole'] = 0 # Initialisation

# %%
# Si la ligne à une valeur dans metropole_name alors cette commune appartient à une métropole :
communes.loc[~pd.isnull(communes.metropole_name), 'is_metropole'] = 1 
# "~" = négation

# %%
communes.is_metropole.value_counts()
# Out:
# 0    36290
# 1      452
# Name: is_metropole, dtype: int64

# %% [markdown]
# ### Selection de variables

# %%
colonnes_a_utiliser = ['Code INSEE', 'Statut', 'Altitude Moyenne', 'Superficie', 'is_metropole', 'metropole_name']

# %%
communes = communes[colonnes_a_utiliser] # Notre Dataframe à uniquement les colonnnes désirés
communes.head()
# Out:
#   Code INSEE            Statut  Altitude Moyenne  Superficie  is_metropole  \
# 0      39007    Commune simple             587.0       582.0             0
# 1      88086    Commune simple             454.0       396.0             0
# 2      62627    Commune simple              49.0       426.0             0
# 3      14020    Commune simple              33.0       987.0             0
# 4      11091  Chef-lieu canton             455.0      1605.0             0
#
#   metropole_name
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %%
# Naming : 
communes.columns = ['COM', 'status', 'mean_altitude', 'superficie', 'is_metropole', 'metropole_name']
communes.head()
# Out:
#      COM            status  mean_altitude  superficie  is_metropole  \
# 0  39007    Commune simple          587.0       582.0             0
# 1  88086    Commune simple          454.0       396.0             0
# 2  62627    Commune simple           49.0       426.0             0
# 3  14020    Commune simple           33.0       987.0             0
# 4  11091  Chef-lieu canton          455.0      1605.0             0
#
#   metropole_name
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %% [markdown]
# ### Extraction :

# %%
communes.to_csv('data/commune_metropole.csv', # Noms du fichiers dans le répertoire "data"
               index=False,                  # On ne souhaite pas extraire les index pandas (0, 1, 2 etc...)
               encoding='utf-8')             # Encoding lorsqu'il y a du texte dans nos données (important !)

# %%
# On test notre nouveau fichier
nouveau_fichier = pd.read_csv('data/commune_metropole.csv',
                             encoding="utf-8")

# %%
nouveau_fichier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36742 entries, 0 to 36741
# Data columns (total 6 columns):
# COM               36742 non-null object
# status            36742 non-null object
# mean_altitude     36742 non-null float64
# superficie        36742 non-null float64
# is_metropole      36742 non-null int64
# metropole_name    452 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
nouve
